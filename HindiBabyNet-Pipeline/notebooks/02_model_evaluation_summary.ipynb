# %% [markdown]
# # Model Evaluation Summary
#
# Load and summarise evaluation outputs produced by `hindibabynet-evaluate-models`.

# %%
from pathlib import Path
import pandas as pd

results_dir = Path("../artifacts/summaries")
files = sorted(results_dir.glob("*.parquet"))
print(f"Found {len(files)} result file(s)")
