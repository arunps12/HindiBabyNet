# %% [markdown]
# # Combined Summary and Quality Checks
#
# This notebook reviews combined participant summaries, linkage quality flags, metadata warnings, and selected combined Wordbank-style tables.

# %%
from hindibabynet_cdi.eda_tables import build_eda_tables
from hindibabynet_cdi.scoring import build_scoring_outputs

outputs = build_scoring_outputs()
combined_tables = build_eda_tables(
    participant_linkage=outputs['participant_linkage'],
    participant_metadata=outputs['participant_metadata'],
    participant_scores=outputs['cdi_combined_participant_scores'],
    category_scores=outputs['cdi_category_scores'],
    word_level_long=outputs['cdi_combined_word_level_long'],
    questionnaire=None,
)
sorted(combined_tables.keys())

# %%
combined_tables['summary'], combined_tables['metadata_warnings'].head()

# %%
outputs['shared_word_production_by_age'].head(), outputs['wordbank_percentile_curves'].head()
