# %% [markdown]
# # Create Metadata and Word Mapping
#
# This notebook generates raw-driven metadata tables, word mappings, duplicate-column diagnostics, and the manual-review file for missing word translations or categories.

# %%
from hindibabynet_cdi.config import load_config
from hindibabynet_cdi.linking import load_pipeline_forms
from hindibabynet_cdi.metadata import generate_metadata_outputs

config = load_config()
forms = load_pipeline_forms(config)
metadata_outputs = generate_metadata_outputs(forms, config=config)
sorted(metadata_outputs.keys())

# %%
metadata_outputs['word_mapping'].head()

# %%
metadata_outputs['missing_word_mapping_to_fill'].head(), metadata_outputs['word_mapping_quality_report']
