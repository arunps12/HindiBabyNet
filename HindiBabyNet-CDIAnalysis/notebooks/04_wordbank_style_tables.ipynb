# %% [markdown]
# # Wordbank-Style Tables
#
# This notebook creates the age, word, category, percentile, and shared-word tables derived from the combined scored long data.

# %%
from hindibabynet_cdi.scoring import build_scoring_outputs

outputs = build_scoring_outputs()
[name for name in outputs if name.startswith('wordbank') or name.startswith('word_frequency') or name.startswith('shared_word')]

# %%
outputs['wordbank_word_by_age'].head(), outputs['wordbank_percentile_curves'].head()
