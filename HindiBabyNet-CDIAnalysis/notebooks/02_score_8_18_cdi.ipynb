# %% [markdown]
# # Score CDI 8-18
#
# This notebook builds the 8-18 participant metadata, raw-column wide scores, safe-column wide scores, and word-level long output.

# %%
from hindibabynet_cdi.scoring import build_scoring_outputs

outputs = build_scoring_outputs()
outputs['cdi_8_18_scored_wide'].head()

# %%
outputs['cdi_8_18_scored_wide_safe_columns'].head()

# %%
outputs['cdi_8_18_word_level_long'].head()
