# %% [markdown]
# # Score CDI 19-36
#
# This notebook builds the 19-36 participant metadata, raw-column wide scores, safe-column wide scores, and word-level long output.

# %%
from hindibabynet_cdi.scoring import build_scoring_outputs

outputs = build_scoring_outputs()
outputs['cdi_19_36_scored_wide'].head()

# %%
outputs['cdi_19_36_scored_wide_safe_columns'].head()

# %%
outputs['cdi_19_36_word_level_long'].head()
